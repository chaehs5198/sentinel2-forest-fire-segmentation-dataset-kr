# %%
# !pip install split-folders

# %%
import splitfolders

# %%
import os

# %%
os.chdir(r"D:\deep_learning\forestfire_activefire_train")

# %%
input_folder = r'D:\deep_learning\forestfire_activefire_train'

# %%
splitfolders.ratio(input_folder, output="data3", seed=1337, ratio=(.8, .1, .1), group_prefix=None)
# Out:
# Copying files: 24124 files [01:03, 378.95 files/s]

# %%
os.chdir(r"D:\deep_learning\forestfire_activefire_train\data2")

# %%
input_folder = r'D:\deep_learning\forestfire_activefire_train\data2'

# %%
splitfolders.ratio(input_folder, output="", seed=1337, ratio=(.8, .1, .1), group_prefix=None)
# Out:
# Copying files: 24124 files [00:27, 878.71 files/s]

# %%
os.chdir(r"D:\deep_learning\forestfire_burnedarea_train\data")

# %%
input_folder = r'D:\deep_learning\forestfire_burnedarea_train\data'

# %%
splitfolders.ratio(input_folder, output="", seed=1337, ratio=(.8, .1, .1), group_prefix=None)
# Out:
# Copying files: 22246 files [00:25, 888.33 files/s]

# %%
os.chdir(r"D:\deep_learning\Sentinel_forestfire\MY_TEST_SENTINEL_IMAGERY_DATA\ready_data")

# %%
input_folder = r'D:\deep_learning\Sentinel_forestfire\MY_TEST_SENTINEL_IMAGERY_DATA\ready_data\data'

# %%
splitfolders.ratio(input_folder, output="", seed=1337, ratio=(.6, .2, .2), group_prefix=None)
# Out:
# Copying files: 768 files [00:02, 306.77 files/s]

# %%
os.chdir(r"D:\deep_learning\Sentinel_forestfire\MY_TEST_SENTINEL_IMAGERY_DATA\mendeley_data")

# %%
input_folder = r'D:\deep_learning\Sentinel_forestfire\MY_TEST_SENTINEL_IMAGERY_DATA\mendeley_data\data'

# %%
splitfolders.ratio(input_folder, output="", seed=1337, ratio=(.6, .2, .2), group_prefix=None)
# Out:
# Copying files: 454 files [00:00, 455.94 files/s]

# %%
os.chdir(r"D:\deep_learning\Sentinel_forestfire\MY_TEST_SENTINEL_IMAGERY_DATA\mine+mendeley_data")

# %%
input_folder = r'D:\deep_learning\Sentinel_forestfire\MY_TEST_SENTINEL_IMAGERY_DATA\mine+mendeley_data\data'

# %%
splitfolders.ratio(input_folder, output="", seed=1337, ratio=(.6, .2, .2), group_prefix=None)
# Out:
# Copying files: 1222 files [00:05, 216.19 files/s]

# %%
os.chdir(r"D:\deep_learning\Sentinel_forestfire\MY_TEST_SENTINEL_IMAGERY_DATA\ready_data_0427")

# %%
input_folder = r'D:\deep_learning\Sentinel_forestfire\MY_TEST_SENTINEL_IMAGERY_DATA\ready_data_0427\data'

# %%
splitfolders.ratio(input_folder, output="", seed=1337, ratio=(.6, .2, .2), group_prefix=None)
# Out:
# Copying files: 962 files [00:00, 1607.30 files/s]
