# %%
import os
from glob import glob

# %%
os.chdir(r'D:\deep_learning\Sentinel_forestfire\MY_TEST_SENTINEL_IMAGERY_DATA\Google_Earth_Engine\data')

# %%
images = glob('image/*.tif')
masks = glob('mask/*.tif')

# %%
masks[0][5:-9]
# Out:
# 'T52SBD_20220402T021559_2022046'

# %%
print(images[0],'\n', masks[0])
# Out:
# image\T52SBD_20220402T021559_2022046.tif
#  mask\T52SBD_20220402T021559_2022046_mask.tif

# %%
for i,j in zip(images, masks):
    checks = []
    if i[6:-4] != j[5:-9]:
        checks.append(i)
        checks.append(j)
    
print(checks)
# Out:
# []
