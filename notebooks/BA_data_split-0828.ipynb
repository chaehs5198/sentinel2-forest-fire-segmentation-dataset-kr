# %%
import splitfolders
import os

# %%
os.chdir(r"D:\deep_learning\Sentinel_forestfire\MY_TEST_SENTINEL_IMAGERY_DATA\imagery_data_complete_0828")

# %%
input_folder = 'data\\'

# %%
splitfolders.ratio(input_folder, output="", seed=165849, ratio=(.8, .1, .1), group_prefix=None)
# Out:
# Copying files: 706 files [00:00, 901.10 files/s]
